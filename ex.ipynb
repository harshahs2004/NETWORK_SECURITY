# %%
import pandas as pd

df = pd.read_csv("/Users/hemanthhs/Documents/NETWORK SECURITY/Network_data/Phising_Detection_Dataset.csv")

print(df["Phising"].isnull().sum())
# Out:
# 32520

# %%
print(df["Phising"].value_counts())
# Out:
# Phising
# 0.0    530060
# 1.0    100011
# Name: count, dtype: int64
